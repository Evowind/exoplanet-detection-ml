# %%
# ==============================================================
# Détection d'Exoplanètes - Multi-Architecture (Colab)
# ==============================================================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from pathlib import Path
from astropy.io import fits
from tqdm import tqdm
import warnings
import os
import pickle

# -----------------------------
# MONTAGE DE DRIVE
# -----------------------------
from google.colab import drive
drive.mount('/content/drive')

warnings.filterwarnings('ignore')

# =============================
# CONFIGURATION
# =============================
tf.random.set_seed(42)
np.random.seed(42)

# -----------------------------
# PARAMÈTRES MODIFIABLES
# -----------------------------
model_type = 'tcn'  # Choisir: 'resnet', 'lstm', 'tcn', 'transformer'
data_path = '/content/drive/MyDrive/data/dataset_fits'  # Dataset sur Drive
target_length = 3197
output_path = '/content/'  # Tout sera sauvegardé localement sur Colab

# ------------------------------------------------------------------
# FONCTIONS DE CHARGEMENT ET NORMALISATION
# ------------------------------------------------------------------
def load_fits_file(filepath):
    try:
        with fits.open(filepath) as hdul:
            for ext in range(len(hdul)):
                data = hdul[ext].data
                if data is not None:
                    flux_columns = ['PDCSAP_FLUX', 'SAP_FLUX', 'FLUX', 'flux']
                    for col in flux_columns:
                        if hasattr(data, col):
                            flux = data[col]
                            return np.nan_to_num(flux, nan=0.0, posinf=0.0, neginf=0.0)
                    if isinstance(data, np.ndarray):
                        if data.ndim == 1:
                            return np.nan_to_num(data, nan=0.0, posinf=0.0, neginf=0.0)
                        elif data.ndim == 2:
                            flux = data[:, 0] if data.shape[1] > 0 else data[0, :]
                            return np.nan_to_num(flux, nan=0.0, posinf=0.0, neginf=0.0)
        print(f"⚠️  Aucune donnée de flux trouvée dans {filepath}")
        return None
    except Exception as e:
        print(f"Erreur lors du chargement de {filepath}: {e}")
        return None

def normalize_length(flux, target_length):
    current_length = len(flux)
    if current_length == target_length:
        return flux
    elif current_length > target_length:
        indices = np.linspace(0, current_length - 1, target_length, dtype=int)
        return flux[indices]
    else:
        old_indices = np.arange(current_length)
        new_indices = np.linspace(0, current_length - 1, target_length)
        return np.interp(new_indices, old_indices, flux)

def robust_normalize(flux):
    median = np.median(flux)
    mad = np.median(np.abs(flux - median))
    if mad == 0: mad = 1e-6
    return (flux - median) / mad

def load_fits_dataset(base_path, split='train', target_length=3197, test_size=0.2):
    from sklearn.model_selection import train_test_split
    base_path = Path(base_path)
    cp_path = base_path / 'CP'
    fp_path = base_path / 'FP'
    if not cp_path.exists() or not fp_path.exists():
        raise ValueError("Les dossiers CP/ et FP/ sont introuvables")
    X, y = [], []
    for f in tqdm(list(cp_path.glob("*.fits")), desc="Chargement CP"):
        flux = load_fits_file(f)
        if flux is not None and len(flux) > 50:
            X.append(normalize_length(flux, target_length))
            y.append(1)
    for f in tqdm(list(fp_path.glob("*.fits")), desc="Chargement FP"):
        flux = load_fits_file(f)
        if flux is not None and len(flux) > 50:
            X.append(normalize_length(flux, target_length))
            y.append(0)
    X = np.array(X)
    y = np.array(y)
    if len(X) == 0:
        raise ValueError("Aucune donnée FITS valide chargée")
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, stratify=y, random_state=42
    )
    if split=='train': return X_train, y_train
    elif split=='test': return X_test, y_test
    else: raise ValueError("split doit être 'train' ou 'test'")

# =============================
# ARCHITECTURES
# =============================
def residual_block(x, filters, kernel_size=3, stride=1, name=''):
    shortcut = x
    x = layers.Conv1D(filters, kernel_size, strides=stride, padding='same',
                      kernel_regularizer=keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Conv1D(filters, kernel_size, padding='same',
                      kernel_regularizer=keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv1D(filters, 1, strides=stride, padding='same')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def build_resnet(input_shape):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv1D(32, 7, strides=2, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling1D(3, strides=2, padding='same')(x)
    x = residual_block(x, 32)
    x = residual_block(x, 32)
    x = residual_block(x, 64, stride=2)
    x = residual_block(x, 64)
    x = residual_block(x, 128, stride=2)
    x = residual_block(x, 128)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inputs, outputs)

def build_lstm(input_shape):
    inputs = keras.Input(shape=input_shape)
    x = layers.LSTM(128, return_sequences=True)(inputs)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LSTM(64, return_sequences=True)(x)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LSTM(32, return_sequences=False)(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inputs, outputs)

def build_tcn(input_shape, num_filters=64, kernel_size=3, dilations=[1,2,4,8,16]):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for i, dilation in enumerate(dilations):
        conv = layers.Conv1D(num_filters, kernel_size, padding='causal',
                             dilation_rate=dilation, activation='relu')(x)
        conv = layers.BatchNormalization()(conv)
        conv = layers.Dropout(0.3)(conv)
        if x.shape[-1] != num_filters:
            x = layers.Conv1D(num_filters, 1, padding='same')(x)
        x = layers.Add()([x, conv])
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inputs, outputs)

def build_transformer(input_shape, num_heads=4, ff_dim=128, num_blocks=3):
    inputs = keras.Input(shape=input_shape)
    x = layers.Dense(64)(inputs)
    for i in range(num_blocks):
        attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=64//num_heads)(x, x)
        attn_output = layers.Dropout(0.3)(attn_output)
        x = layers.Add()([x, attn_output])
        x = layers.LayerNormalization(epsilon=1e-6)(x)
        ffn = layers.Dense(ff_dim, activation='relu')(x)
        ffn = layers.Dropout(0.3)(ffn)
        ffn = layers.Dense(64)(ffn)
        x = layers.Add()([x, ffn])
        x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inputs, outputs)

# =============================
# FOCAL LOSS
# =============================
def focal_loss(gamma=2.0, alpha=0.25):
    def fl(y_true, y_pred):
        epsilon = keras.backend.epsilon()
        y_pred = keras.backend.clip(y_pred, epsilon, 1.0 - epsilon)
        y_true = tf.cast(y_true, tf.float32)
        ce = -y_true * keras.backend.log(y_pred)
        weight = alpha * y_true * keras.backend.pow(1 - y_pred, gamma)
        ce_neg = -(1 - y_true) * keras.backend.log(1 - y_pred)
        weight_neg = (1 - alpha) * (1 - y_true) * keras.backend.pow(y_pred, gamma)
        loss = weight * ce + weight_neg * ce_neg
        return keras.backend.mean(loss)
    return fl

# =============================
# ENTRAÎNEMENT
# =============================
def train_model(model_type='lstm', data_path=data_path, target_length=target_length):
    print(f"\n=== Entraînement {model_type.upper()} ===\n")
    X_train, y_train = load_fits_dataset(data_path, split='train', target_length=target_length)
    X_test, y_test = load_fits_dataset(data_path, split='test', target_length=target_length)

    # Normalisation robuste
    X_train = np.array([robust_normalize(f) for f in X_train])
    X_test = np.array([robust_normalize(f) for f in X_test])
    X_train = np.clip(X_train, -10, 10).reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = np.clip(X_test, -10, 10).reshape(X_test.shape[0], X_test.shape[1], 1)

    input_shape = (X_train.shape[1], 1)
    if model_type.lower()=='resnet': model = build_resnet(input_shape)
    elif model_type.lower()=='lstm': model = build_lstm(input_shape)
    elif model_type.lower()=='tcn': model = build_tcn(input_shape)
    elif model_type.lower()=='transformer': model = build_transformer(input_shape)
    else: raise ValueError("Modèle non reconnu")

    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    model.compile(optimizer=keras.optimizers.Adam(1e-4),
                  loss=focal_loss(alpha=0.75),
                  metrics=[keras.metrics.BinaryAccuracy(name='accuracy'),
                           keras.metrics.Precision(name='precision'),
                           keras.metrics.Recall(name='recall'),
                           keras.metrics.AUC(name='auc')])

    callbacks = [
        EarlyStopping(monitor='val_auc', patience=20, restore_best_weights=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7, verbose=1),
        ModelCheckpoint(f'{output_path}best_{model_type}_exoplanet.h5', monitor='val_auc',
                        mode='max', save_best_only=True, verbose=1)
    ]

    history = model.fit(X_train, y_train,
                        epochs=100,
                        batch_size=32,
                        validation_data=(X_test, y_test),
                        class_weight=class_weight_dict,
                        callbacks=callbacks,
                        verbose=1)

    # Évaluation
    y_pred_proba = model.predict(X_test).flatten()
    thresholds = np.arange(0.55,0.66,0.01)
    best_f1, best_threshold = 0, 0.6
    for th in thresholds:
        y_pred_temp = (y_pred_proba>th).astype(int)
        prec = np.sum((y_pred_temp==1)&(y_test==1))/max(np.sum(y_pred_temp==1),1)
        rec = np.sum((y_pred_temp==1)&(y_test==1))/max(np.sum(y_test==1),1)
        f1 = 2*prec*rec/max(prec+rec,1e-6)
        if f1>best_f1: best_f1, best_threshold = f1, th
    y_pred = (y_pred_proba>best_threshold).astype(int)
    print("\n=== Classification Report ===")
    print(classification_report(y_test, y_pred, target_names=['FP','CP'], digits=4, zero_division=0))

    # Sauvegarde
    model.save(f'{output_path}{model_type}_exoplanet_fits_final.h5')
    with open(f'{output_path}{model_type}_best_threshold_fits.pkl','wb') as f: pickle.dump(best_threshold,f)
    print(f"\n✅ Modèle et seuil sauvegardés dans {output_path}")

    # =============================
    # VISUALISATIONS
    # =============================
    print("\n[VISUALISATION] Génération des graphiques...")

    cm = confusion_matrix(y_test, y_pred)

    plt.style.use('seaborn-v0_8-darkgrid')
    fig = plt.figure(figsize=(16, 10))

    # 1. Loss
    plt.subplot(2, 3, 1)
    plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
    plt.plot(history.history['val_loss'], label='Val Loss', linewidth=2)
    plt.title(f'{model_type.upper()} - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(alpha=0.3)

    # 2. Accuracy
    plt.subplot(2, 3, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Val Accuracy', linewidth=2)
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(alpha=0.3)

    # 3. AUC
    plt.subplot(2, 3, 3)
    plt.plot(history.history['auc'], label='Train AUC', linewidth=2)
    plt.plot(history.history['val_auc'], label='Val AUC', linewidth=2)
    plt.title('AUC')
    plt.xlabel('Epoch')
    plt.ylabel('AUC')
    plt.legend()
    plt.grid(alpha=0.3)

    # 4. Matrice de confusion
    plt.subplot(2, 3, 4)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['FP', 'CP'],
                yticklabels=['FP', 'CP'])
    plt.title('Matrice de Confusion')
    plt.xlabel('Classe prédite')
    plt.ylabel('Classe réelle')

    # 5. Courbe ROC
    plt.subplot(2, 3, 5)
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, linewidth=2, label=f'AUC = {roc_auc:.4f}')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.title('Courbe ROC')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.grid(alpha=0.3)

    # 6. Distribution des probabilités
    plt.subplot(2, 3, 6)
    plt.hist(y_pred_proba[y_test == 0], bins=50, alpha=0.6, label='FP')
    plt.hist(y_pred_proba[y_test == 1], bins=50, alpha=0.6, label='CP')
    plt.axvline(best_threshold, color='black', linestyle='--',
                label=f'Seuil={best_threshold:.2f}')
    plt.title('Distribution des probabilités')
    plt.xlabel('Probabilité prédite')
    plt.ylabel('Fréquence')
    plt.legend()
    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.savefig(f'{output_path}{model_type}_results.png', dpi=300, bbox_inches='tight')
    plt.show()

    print(f"✔ Graphiques sauvegardés dans {output_path}{model_type}_results.png")

# =============================
# LANCEMENT
# =============================
train_model(model_type=model_type, data_path=data_path, target_length=target_length)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# === Entraînement TCN ===
# Chargement CP: 100%|██████████| 2831/2831 [01:45<00:00, 26.73it/s]
# Chargement FP: 100%|██████████| 1926/1926 [00:47<00:00, 40.49it/s]
# Chargement CP: 100%|██████████| 2831/2831 [01:11<00:00, 39.85it/s]
# Chargement FP: 100%|██████████| 1926/1926 [00:35<00:00, 54.97it/s]
# Epoch 1/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5887 - auc: 0.5240 - loss: 0.0818 - precision: 0.6133 - recall: 0.8644
# Epoch 1: val_auc improved from -inf to 0.51871, saving model to /content/best_tcn_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 36s 175ms/step - accuracy: 0.5887 - auc: 0.5240 - loss: 0.0818 - precision: 0.6132 - recall: 0.8649 - val_accuracy: 0.5956 - val_auc: 0.5187 - val_loss: 0.0687 - val_precision: 0.5956 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 2/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6022 - auc: 0.5307 - loss: 0.0725 - precision: 0.6042 - recall: 0.9844
# Epoch 2: val_auc improved from 0.51871 to 0.54366, saving model to /content/best_tcn_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.6022 - auc: 0.5309 - loss: 0.0725 - precision: 0.6041 - recall: 0.9843 - val_accuracy: 0.5956 - val_auc: 0.5437 - val_loss: 0.0791 - val_precision: 0.5956 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 3/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6144 - auc: 0.5578 - loss: 0.0703 - precision: 0.6108 - recall: 0.9910
# Epoch 3: val_auc improved from 0.54366 to 0.56394, saving model to /content/best_tcn_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6142 - auc: 0.5578 - loss: 0.0703 - precision: 0.6107 - recall: 0.9910 - val_accuracy: 0.5956 - val_auc: 0.5639 - val_loss: 0.0849 - val_precision: 0.5956 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 4/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6162 - auc: 0.5744 - loss: 0.0687 - precision: 0.6122 - recall: 0.9889
# Epoch 4: val_auc improved from 0.56394 to 0.57995, saving model to /content/best_tcn_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.6161 - auc: 0.5744 - loss: 0.0687 - precision: 0.6121 - recall: 0.9890 - val_accuracy: 0.5956 - val_auc: 0.5799 - val_loss: 0.0818 - val_precision: 0.5956 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 5/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6224 - auc: 0.5896 - loss: 0.0675 - precision: 0.6154 - recall: 0.9940
# Epoch 5: val_auc improved from 0.57995 to 0.58872, saving model to /content/best_tcn_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6222 - auc: 0.5896 - loss: 0.0675 - precision: 0.6153 - recall: 0.9940 - val_accuracy: 0.5966 - val_auc: 0.5887 - val_loss: 0.0799 - val_precision: 0.5962 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 6/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6277 - auc: 0.5995 - loss: 0.0664 - precision: 0.6187 - recall: 0.9946
# Epoch 6: val_auc improved from 0.58872 to 0.59248, saving model to /content/best_tcn_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.6276 - auc: 0.5994 - loss: 0.0664 - precision: 0.6186 - recall: 0.9946 - val_accuracy: 0.5977 - val_auc: 0.5925 - val_loss: 0.0749 - val_precision: 0.5968 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 7/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6294 - auc: 0.5953 - loss: 0.0661 - precision: 0.6196 - recall: 0.9954
# Epoch 7: val_auc improved from 0.59248 to 0.59497, saving model to /content/best_tcn_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6292 - auc: 0.5953 - loss: 0.0661 - precision: 0.6195 - recall: 0.9953 - val_accuracy: 0.6029 - val_auc: 0.5950 - val_loss: 0.0720 - val_precision: 0.6000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 8/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6424 - auc: 0.6094 - loss: 0.0650 - precision: 0.6283 - recall: 0.9946
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 8: val_auc improved from 0.59497 to 0.60103, saving model to /content/best_tcn_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.6422 - auc: 0.6093 - loss: 0.0651 - precision: 0.6281 - recall: 0.9945 - val_accuracy: 0.6040 - val_auc: 0.6010 - val_loss: 0.0747 - val_precision: 0.6006 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 9/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6386 - auc: 0.6355 - loss: 0.0642 - precision: 0.6252 - recall: 0.9978
# Epoch 9: val_auc did not improve from 0.60103
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.6385 - auc: 0.6354 - loss: 0.0642 - precision: 0.6252 - recall: 0.9978 - val_accuracy: 0.6061 - val_auc: 0.5973 - val_loss: 0.0744 - val_precision: 0.6019 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 10/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6415 - auc: 0.6335 - loss: 0.0644 - precision: 0.6280 - recall: 0.9920
# Epoch 10: val_auc did not improve from 0.60103
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6414 - auc: 0.6334 - loss: 0.0644 - precision: 0.6280 - recall: 0.9920 - val_accuracy: 0.6124 - val_auc: 0.5969 - val_loss: 0.0714 - val_precision: 0.6058 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 11/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6450 - auc: 0.6206 - loss: 0.0653 - precision: 0.6301 - recall: 0.9942
# Epoch 11: val_auc did not improve from 0.60103
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.6448 - auc: 0.6204 - loss: 0.0653 - precision: 0.6299 - recall: 0.9942 - val_accuracy: 0.6124 - val_auc: 0.5973 - val_loss: 0.0746 - val_precision: 0.6058 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 12/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6413 - auc: 0.6451 - loss: 0.0646 - precision: 0.6278 - recall: 0.9933
# Epoch 12: val_auc did not improve from 0.60103
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6411 - auc: 0.6447 - loss: 0.0646 - precision: 0.6276 - recall: 0.9933 - val_accuracy: 0.6145 - val_auc: 0.5978 - val_loss: 0.0722 - val_precision: 0.6071 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 13/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6469 - auc: 0.6518 - loss: 0.0630 - precision: 0.6314 - recall: 0.9936
# Epoch 13: val_auc did not improve from 0.60103
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.6468 - auc: 0.6516 - loss: 0.0631 - precision: 0.6313 - recall: 0.9936 - val_accuracy: 0.6145 - val_auc: 0.6007 - val_loss: 0.0718 - val_precision: 0.6071 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 14/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6466 - auc: 0.6474 - loss: 0.0633 - precision: 0.6310 - recall: 0.9950
# Epoch 14: val_auc improved from 0.60103 to 0.60649, saving model to /content/best_tcn_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.6465 - auc: 0.6473 - loss: 0.0633 - precision: 0.6309 - recall: 0.9950 - val_accuracy: 0.6176 - val_auc: 0.6065 - val_loss: 0.0709 - val_precision: 0.6090 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 15/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6535 - auc: 0.6366 - loss: 0.0634 - precision: 0.6356 - recall: 0.9952
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 15: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6533 - auc: 0.6365 - loss: 0.0635 - precision: 0.6354 - recall: 0.9952 - val_accuracy: 0.6187 - val_auc: 0.6040 - val_loss: 0.0702 - val_precision: 0.6097 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 16/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6476 - auc: 0.6409 - loss: 0.0635 - precision: 0.6317 - recall: 0.9942
# Epoch 16: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6474 - auc: 0.6406 - loss: 0.0635 - precision: 0.6316 - recall: 0.9942 - val_accuracy: 0.6187 - val_auc: 0.6013 - val_loss: 0.0699 - val_precision: 0.6097 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 17/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6506 - auc: 0.6390 - loss: 0.0635 - precision: 0.6338 - recall: 0.9939
# Epoch 17: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6505 - auc: 0.6389 - loss: 0.0635 - precision: 0.6337 - recall: 0.9939 - val_accuracy: 0.6229 - val_auc: 0.6007 - val_loss: 0.0701 - val_precision: 0.6123 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 18/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6512 - auc: 0.6380 - loss: 0.0636 - precision: 0.6344 - recall: 0.9931
# Epoch 18: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6510 - auc: 0.6379 - loss: 0.0636 - precision: 0.6343 - recall: 0.9931 - val_accuracy: 0.6229 - val_auc: 0.5994 - val_loss: 0.0699 - val_precision: 0.6123 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 19/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6501 - auc: 0.6516 - loss: 0.0637 - precision: 0.6337 - recall: 0.9929
# Epoch 19: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6499 - auc: 0.6514 - loss: 0.0637 - precision: 0.6335 - recall: 0.9929 - val_accuracy: 0.6208 - val_auc: 0.5995 - val_loss: 0.0698 - val_precision: 0.6110 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 20/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6529 - auc: 0.6538 - loss: 0.0632 - precision: 0.6355 - recall: 0.9932
# Epoch 20: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6527 - auc: 0.6535 - loss: 0.0633 - precision: 0.6354 - recall: 0.9932 - val_accuracy: 0.6229 - val_auc: 0.5972 - val_loss: 0.0692 - val_precision: 0.6123 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 21/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6525 - auc: 0.6442 - loss: 0.0626 - precision: 0.6346 - recall: 0.9964
# Epoch 21: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6523 - auc: 0.6439 - loss: 0.0627 - precision: 0.6345 - recall: 0.9963 - val_accuracy: 0.6229 - val_auc: 0.5954 - val_loss: 0.0691 - val_precision: 0.6123 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 22/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6562 - auc: 0.6493 - loss: 0.0628 - precision: 0.6373 - recall: 0.9956
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 22: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6561 - auc: 0.6492 - loss: 0.0628 - precision: 0.6372 - recall: 0.9956 - val_accuracy: 0.6239 - val_auc: 0.6005 - val_loss: 0.0696 - val_precision: 0.6130 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 23/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6481 - auc: 0.6477 - loss: 0.0636 - precision: 0.6324 - recall: 0.9922
# Epoch 23: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6480 - auc: 0.6476 - loss: 0.0636 - precision: 0.6324 - recall: 0.9922 - val_accuracy: 0.6250 - val_auc: 0.5971 - val_loss: 0.0693 - val_precision: 0.6136 - val_recall: 1.0000 - learning_rate: 1.2500e-05
# Epoch 24/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6526 - auc: 0.6562 - loss: 0.0629 - precision: 0.6355 - recall: 0.9922
# Epoch 24: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6524 - auc: 0.6560 - loss: 0.0629 - precision: 0.6354 - recall: 0.9921 - val_accuracy: 0.6239 - val_auc: 0.6007 - val_loss: 0.0698 - val_precision: 0.6130 - val_recall: 1.0000 - learning_rate: 1.2500e-05
# Epoch 25/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6519 - auc: 0.6482 - loss: 0.0632 - precision: 0.6350 - recall: 0.9921
# Epoch 25: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6518 - auc: 0.6480 - loss: 0.0633 - precision: 0.6349 - recall: 0.9921 - val_accuracy: 0.6239 - val_auc: 0.5988 - val_loss: 0.0698 - val_precision: 0.6130 - val_recall: 1.0000 - learning_rate: 1.2500e-05
# Epoch 26/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6507 - auc: 0.6586 - loss: 0.0624 - precision: 0.6349 - recall: 0.9889
# Epoch 26: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.6506 - auc: 0.6583 - loss: 0.0624 - precision: 0.6347 - recall: 0.9890 - val_accuracy: 0.6239 - val_auc: 0.5996 - val_loss: 0.0701 - val_precision: 0.6130 - val_recall: 1.0000 - learning_rate: 1.2500e-05
# Epoch 27/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6565 - auc: 0.6503 - loss: 0.0628 - precision: 0.6374 - recall: 0.9963
# Epoch 27: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6563 - auc: 0.6501 - loss: 0.0629 - precision: 0.6373 - recall: 0.9962 - val_accuracy: 0.6250 - val_auc: 0.5977 - val_loss: 0.0689 - val_precision: 0.6136 - val_recall: 1.0000 - learning_rate: 1.2500e-05
# Epoch 28/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6479 - auc: 0.6537 - loss: 0.0631 - precision: 0.6321 - recall: 0.9935
# Epoch 28: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.6478 - auc: 0.6533 - loss: 0.0631 - precision: 0.6320 - recall: 0.9935 - val_accuracy: 0.6250 - val_auc: 0.5962 - val_loss: 0.0690 - val_precision: 0.6136 - val_recall: 1.0000 - learning_rate: 1.2500e-05
# Epoch 29/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6508 - auc: 0.6502 - loss: 0.0630 - precision: 0.6339 - recall: 0.9943
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 29: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6507 - auc: 0.6499 - loss: 0.0630 - precision: 0.6338 - recall: 0.9943 - val_accuracy: 0.6250 - val_auc: 0.5967 - val_loss: 0.0689 - val_precision: 0.6136 - val_recall: 1.0000 - learning_rate: 1.2500e-05
# Epoch 30/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6552 - auc: 0.6386 - loss: 0.0630 - precision: 0.6372 - recall: 0.9926
# Epoch 30: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.6551 - auc: 0.6384 - loss: 0.0630 - precision: 0.6370 - recall: 0.9926 - val_accuracy: 0.6250 - val_auc: 0.5971 - val_loss: 0.0693 - val_precision: 0.6136 - val_recall: 1.0000 - learning_rate: 6.2500e-06
# Epoch 31/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6528 - auc: 0.6622 - loss: 0.0621 - precision: 0.6357 - recall: 0.9919
# Epoch 31: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6527 - auc: 0.6619 - loss: 0.0622 - precision: 0.6356 - recall: 0.9919 - val_accuracy: 0.6250 - val_auc: 0.5988 - val_loss: 0.0691 - val_precision: 0.6136 - val_recall: 1.0000 - learning_rate: 6.2500e-06
# Epoch 32/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6564 - auc: 0.6457 - loss: 0.0626 - precision: 0.6377 - recall: 0.9941
# Epoch 32: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6562 - auc: 0.6456 - loss: 0.0626 - precision: 0.6376 - recall: 0.9941 - val_accuracy: 0.6250 - val_auc: 0.5990 - val_loss: 0.0689 - val_precision: 0.6136 - val_recall: 1.0000 - learning_rate: 6.2500e-06
# Epoch 33/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6490 - auc: 0.6426 - loss: 0.0632 - precision: 0.6336 - recall: 0.9890
# Epoch 33: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.6490 - auc: 0.6425 - loss: 0.0632 - precision: 0.6336 - recall: 0.9890 - val_accuracy: 0.6250 - val_auc: 0.5956 - val_loss: 0.0689 - val_precision: 0.6136 - val_recall: 1.0000 - learning_rate: 6.2500e-06
# Epoch 34/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6544 - auc: 0.6597 - loss: 0.0626 - precision: 0.6362 - recall: 0.9951
# Epoch 34: val_auc did not improve from 0.60649
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.6543 - auc: 0.6596 - loss: 0.0626 - precision: 0.6361 - recall: 0.9951 - val_accuracy: 0.6250 - val_auc: 0.5974 - val_loss: 0.0687 - val_precision: 0.6136 - val_recall: 1.0000 - learning_rate: 6.2500e-06
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === Classification Report ===
#               precision    recall  f1-score   support
#
#           FP     0.8229    0.2052    0.3285       385
#           CP     0.6425    0.9700    0.7730       567
#
#     accuracy                         0.6607       952
#    macro avg     0.7327    0.5876    0.5507       952
# weighted avg     0.7155    0.6607    0.5932       952
#
#
# ✅ Modèle et seuil sauvegardés dans /content/
#
# [VISUALISATION] Génération des graphiques...
# ✔ Graphiques sauvegardés dans /content/tcn_results.png
