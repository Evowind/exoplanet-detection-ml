# %%
# ==============================================================
# Détection d'Exoplanètes - Multi-Architecture (Kaggle)
# ==============================================================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from pathlib import Path
from astropy.io import fits
from tqdm import tqdm
import warnings
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, auc

warnings.filterwarnings('ignore')

# =============================
# CONFIGURATION
# =============================
tf.random.set_seed(42)
np.random.seed(42)

# -----------------------------
# PARAMÈTRES MODIFIABLES
# -----------------------------
model_type = 'lstm'  # Choisir: 'resnet', 'lstm', 'tcn', 'transformer'
data_path = '/kaggle/input/datasetfit/dataset_fits'  # Dataset Kaggle
target_length = 3197
output_path = '/kaggle/working/'  # Tout sera sauvegardé ici

# ------------------------------------------------------------------
# FONCTIONS DE CHARGEMENT ET NORMALISATION
# ------------------------------------------------------------------
def load_fits_file(filepath):
    try:
        with fits.open(filepath) as hdul:
            for ext in range(len(hdul)):
                data = hdul[ext].data
                if data is not None:
                    flux_columns = ['PDCSAP_FLUX', 'SAP_FLUX', 'FLUX', 'flux']
                    for col in flux_columns:
                        if hasattr(data, col):
                            flux = data[col]
                            return np.nan_to_num(flux, nan=0.0, posinf=0.0, neginf=0.0)
                    if isinstance(data, np.ndarray):
                        if data.ndim == 1:
                            return np.nan_to_num(data, nan=0.0, posinf=0.0, neginf=0.0)
                        elif data.ndim == 2:
                            flux = data[:, 0] if data.shape[1] > 0 else data[0, :]
                            return np.nan_to_num(flux, nan=0.0, posinf=0.0, neginf=0.0)
        print(f"⚠️  Aucune donnée de flux trouvée dans {filepath}")
        return None
    except Exception as e:
        print(f"Erreur lors du chargement de {filepath}: {e}")
        return None

def normalize_length(flux, target_length):
    current_length = len(flux)
    if current_length == target_length:
        return flux
    elif current_length > target_length:
        indices = np.linspace(0, current_length - 1, target_length, dtype=int)
        return flux[indices]
    else:
        old_indices = np.arange(current_length)
        new_indices = np.linspace(0, current_length - 1, target_length)
        return np.interp(new_indices, old_indices, flux)

def robust_normalize(flux):
    median = np.median(flux)
    mad = np.median(np.abs(flux - median))
    if mad == 0: mad = 1e-6
    return (flux - median) / mad

def load_fits_dataset(base_path, split='train', target_length=3197, test_size=0.2):
    from sklearn.model_selection import train_test_split
    base_path = Path(base_path)
    cp_path = base_path / 'CP'
    fp_path = base_path / 'FP'
    if not cp_path.exists() or not fp_path.exists():
        raise ValueError("Les dossiers CP/ et FP/ sont introuvables")
    X, y = [], []
    for f in tqdm(list(cp_path.glob("*.fits")), desc="Chargement CP"):
        flux = load_fits_file(f)
        if flux is not None and len(flux) > 50:
            X.append(normalize_length(flux, target_length))
            y.append(1)
    for f in tqdm(list(fp_path.glob("*.fits")), desc="Chargement FP"):
        flux = load_fits_file(f)
        if flux is not None and len(flux) > 50:
            X.append(normalize_length(flux, target_length))
            y.append(0)
    X = np.array(X)
    y = np.array(y)
    if len(X) == 0:
        raise ValueError("Aucune donnée FITS valide chargée")
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, stratify=y, random_state=42
    )
    if split=='train': return X_train, y_train
    elif split=='test': return X_test, y_test
    else: raise ValueError("split doit être 'train' ou 'test'")

# =============================
# ARCHITECTURES
# =============================
def residual_block(x, filters, kernel_size=3, stride=1, name=''):
    shortcut = x
    x = layers.Conv1D(filters, kernel_size, strides=stride, padding='same',
                      kernel_regularizer=keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Conv1D(filters, kernel_size, padding='same',
                      kernel_regularizer=keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv1D(filters, 1, strides=stride, padding='same')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def build_resnet(input_shape):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv1D(32, 7, strides=2, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling1D(3, strides=2, padding='same')(x)
    x = residual_block(x, 32)
    x = residual_block(x, 32)
    x = residual_block(x, 64, stride=2)
    x = residual_block(x, 64)
    x = residual_block(x, 128, stride=2)
    x = residual_block(x, 128)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inputs, outputs)

def build_lstm(input_shape):
    inputs = keras.Input(shape=input_shape)
    x = layers.LSTM(128, return_sequences=True)(inputs)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LSTM(64, return_sequences=True)(x)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LSTM(32, return_sequences=False)(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inputs, outputs)

def build_tcn(input_shape, num_filters=64, kernel_size=3, dilations=[1,2,4,8,16]):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for i, dilation in enumerate(dilations):
        conv = layers.Conv1D(num_filters, kernel_size, padding='causal',
                             dilation_rate=dilation, activation='relu')(x)
        conv = layers.BatchNormalization()(conv)
        conv = layers.Dropout(0.3)(conv)
        if x.shape[-1] != num_filters:
            x = layers.Conv1D(num_filters, 1, padding='same')(x)
        x = layers.Add()([x, conv])
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inputs, outputs)

def build_transformer(input_shape, num_heads=4, ff_dim=128, num_blocks=3):
    inputs = keras.Input(shape=input_shape)
    x = layers.Dense(64)(inputs)
    for i in range(num_blocks):
        attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=64//num_heads)(x, x)
        attn_output = layers.Dropout(0.3)(attn_output)
        x = layers.Add()([x, attn_output])
        x = layers.LayerNormalization(epsilon=1e-6)(x)
        ffn = layers.Dense(ff_dim, activation='relu')(x)
        ffn = layers.Dropout(0.3)(ffn)
        ffn = layers.Dense(64)(ffn)
        x = layers.Add()([x, ffn])
        x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inputs, outputs)

# =============================
# FOCAL LOSS
# =============================
def focal_loss(gamma=2.0, alpha=0.25):
    def fl(y_true, y_pred):
        epsilon = keras.backend.epsilon()
        y_pred = keras.backend.clip(y_pred, epsilon, 1.0 - epsilon)
        y_true = tf.cast(y_true, tf.float32)
        ce = -y_true * keras.backend.log(y_pred)
        weight = alpha * y_true * keras.backend.pow(1 - y_pred, gamma)
        ce_neg = -(1 - y_true) * keras.backend.log(1 - y_pred)
        weight_neg = (1 - alpha) * (1 - y_true) * keras.backend.pow(y_pred, gamma)
        loss = weight * ce + weight_neg * ce_neg
        return keras.backend.mean(loss)
    return fl

# =============================
# ENTRAÎNEMENT
# =============================
def train_model(model_type='lstm', data_path=data_path, target_length=target_length):
    print(f"\n=== Entraînement {model_type.upper()} ===\n")
    X_train, y_train = load_fits_dataset(data_path, split='train', target_length=target_length)
    X_test, y_test = load_fits_dataset(data_path, split='test', target_length=target_length)
    
    # Normalisation robuste
    X_train = np.array([robust_normalize(f) for f in X_train])
    X_test = np.array([robust_normalize(f) for f in X_test])
    X_train = np.clip(X_train, -10, 10).reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = np.clip(X_test, -10, 10).reshape(X_test.shape[0], X_test.shape[1], 1)

    input_shape = (X_train.shape[1], 1)
    if model_type.lower()=='resnet': model = build_resnet(input_shape)
    elif model_type.lower()=='lstm': model = build_lstm(input_shape)
    elif model_type.lower()=='tcn': model = build_tcn(input_shape)
    elif model_type.lower()=='transformer': model = build_transformer(input_shape)
    else: raise ValueError("Modèle non reconnu")

    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    model.compile(optimizer=keras.optimizers.Adam(1e-4),
                  loss=focal_loss(alpha=0.75),
                  metrics=[keras.metrics.BinaryAccuracy(name='accuracy'),
                           keras.metrics.Precision(name='precision'),
                           keras.metrics.Recall(name='recall'),
                           keras.metrics.AUC(name='auc')])

    callbacks = [
        EarlyStopping(monitor='val_auc', patience=20, restore_best_weights=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7, verbose=1),
        ModelCheckpoint(f'{output_path}best_{model_type}_exoplanet.h5', monitor='val_auc',
                        mode='max', save_best_only=True, verbose=1)
    ]

    history = model.fit(X_train, y_train,
                        epochs=100,
                        batch_size=32,
                        validation_data=(X_test, y_test),
                        class_weight=class_weight_dict,
                        callbacks=callbacks,
                        verbose=1)

    # Évaluation
    y_pred_proba = model.predict(X_test).flatten()
    thresholds = np.arange(0.55,0.66,0.01)
    best_f1, best_threshold = 0, 0.6
    for th in thresholds:
        y_pred_temp = (y_pred_proba>th).astype(int)
        prec = np.sum((y_pred_temp==1)&(y_test==1))/max(np.sum(y_pred_temp==1),1)
        rec = np.sum((y_pred_temp==1)&(y_test==1))/max(np.sum(y_test==1),1)
        f1 = 2*prec*rec/max(prec+rec,1e-6)
        if f1>best_f1: best_f1, best_threshold = f1, th
    y_pred = (y_pred_proba>best_threshold).astype(int)
    print("\n=== Classification Report ===")
    print(classification_report(y_test, y_pred, target_names=['FP','CP'], digits=4, zero_division=0))

    # Sauvegarde
    model.save(f'{output_path}{model_type}_exoplanet_fits_final.h5')
    with open(f'{output_path}{model_type}_best_threshold_fits.pkl','wb') as f: pickle.dump(best_threshold,f)
    print(f"\n✅ Modèle et seuil sauvegardés dans {output_path}")

    # =============================
    # VISUALISATIONS
    # =============================
    print("\n[VISUALISATION] Génération des graphiques...")
    
    cm = confusion_matrix(y_test, y_pred)
    
    plt.style.use('seaborn-v0_8-darkgrid')
    fig = plt.figure(figsize=(16, 10))
    
    # 1. Loss
    plt.subplot(2, 3, 1)
    plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
    plt.plot(history.history['val_loss'], label='Val Loss', linewidth=2)
    plt.title(f'{model_type.upper()} - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 2. Accuracy
    plt.subplot(2, 3, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Val Accuracy', linewidth=2)
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 3. AUC
    plt.subplot(2, 3, 3)
    plt.plot(history.history['auc'], label='Train AUC', linewidth=2)
    plt.plot(history.history['val_auc'], label='Val AUC', linewidth=2)
    plt.title('AUC')
    plt.xlabel('Epoch')
    plt.ylabel('AUC')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 4. Matrice de confusion
    plt.subplot(2, 3, 4)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['FP', 'CP'],
                yticklabels=['FP', 'CP'])
    plt.title('Matrice de Confusion')
    plt.xlabel('Classe prédite')
    plt.ylabel('Classe réelle')
    
    # 5. Courbe ROC
    plt.subplot(2, 3, 5)
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, linewidth=2, label=f'AUC = {roc_auc:.4f}')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.title('Courbe ROC')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 6. Distribution des probabilités
    plt.subplot(2, 3, 6)
    plt.hist(y_pred_proba[y_test == 0], bins=50, alpha=0.6, label='FP')
    plt.hist(y_pred_proba[y_test == 1], bins=50, alpha=0.6, label='CP')
    plt.axvline(best_threshold, color='black', linestyle='--',
                label=f'Seuil={best_threshold:.2f}')
    plt.title('Distribution des probabilités')
    plt.xlabel('Probabilité prédite')
    plt.ylabel('Fréquence')
    plt.legend()
    plt.grid(alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f'{output_path}{model_type}_results.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"✔ Graphiques sauvegardés dans {output_path}{model_type}_results.png")

# =============================
# LANCEMENT
# =============================
train_model(model_type=model_type, data_path=data_path, target_length=target_length)
# Out:
# === Entraînement LSTM ===
# Chargement CP: 100%|██████████| 2831/2831 [00:30<00:00, 91.67it/s]
# Chargement FP: 100%|██████████| 1926/1926 [00:20<00:00, 91.97it/s]
# Chargement CP: 100%|██████████| 2831/2831 [00:29<00:00, 97.25it/s]
# Chargement FP: 100%|██████████| 1926/1926 [00:19<00:00, 100.07it/s]
# Epoch 1/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.5764 - auc: 0.4947 - loss: 0.0834 - precision: 0.6038 - recall: 0.8615
# Epoch 1: val_auc improved from -inf to 0.50836, saving model to /kaggle/working/best_lstm_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 37s 280ms/step - accuracy: 0.5764 - auc: 0.4948 - loss: 0.0834 - precision: 0.6038 - recall: 0.8618 - val_accuracy: 0.5945 - val_auc: 0.5084 - val_loss: 0.0802 - val_precision: 0.5952 - val_recall: 0.9982 - learning_rate: 1.0000e-04
# Epoch 2/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6034 - auc: 0.5143 - loss: 0.0780 - precision: 0.6110 - recall: 0.9392
# Epoch 2: val_auc improved from 0.50836 to 0.52002, saving model to /kaggle/working/best_lstm_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 271ms/step - accuracy: 0.6033 - auc: 0.5143 - loss: 0.0780 - precision: 0.6109 - recall: 0.9391 - val_accuracy: 0.5956 - val_auc: 0.5200 - val_loss: 0.0726 - val_precision: 0.5956 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 3/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6015 - auc: 0.5117 - loss: 0.0760 - precision: 0.6082 - recall: 0.9499
# Epoch 3: val_auc did not improve from 0.52002
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 271ms/step - accuracy: 0.6014 - auc: 0.5117 - loss: 0.0760 - precision: 0.6082 - recall: 0.9499 - val_accuracy: 0.5956 - val_auc: 0.5164 - val_loss: 0.0702 - val_precision: 0.5956 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 4/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.5978 - auc: 0.5138 - loss: 0.0752 - precision: 0.6050 - recall: 0.9563
# Epoch 4: val_auc improved from 0.52002 to 0.52620, saving model to /kaggle/working/best_lstm_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 273ms/step - accuracy: 0.5977 - auc: 0.5138 - loss: 0.0752 - precision: 0.6050 - recall: 0.9564 - val_accuracy: 0.5977 - val_auc: 0.5262 - val_loss: 0.0691 - val_precision: 0.5968 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 5/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.5977 - auc: 0.5197 - loss: 0.0747 - precision: 0.6044 - recall: 0.9607
# Epoch 5: val_auc improved from 0.52620 to 0.52850, saving model to /kaggle/working/best_lstm_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.5977 - auc: 0.5197 - loss: 0.0747 - precision: 0.6044 - recall: 0.9607 - val_accuracy: 0.5987 - val_auc: 0.5285 - val_loss: 0.0690 - val_precision: 0.5975 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 6/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.5956 - auc: 0.5194 - loss: 0.0739 - precision: 0.6020 - recall: 0.9678
# Epoch 6: val_auc improved from 0.52850 to 0.54562, saving model to /kaggle/working/best_lstm_exoplanet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.5955 - auc: 0.5194 - loss: 0.0740 - precision: 0.6020 - recall: 0.9678 - val_accuracy: 0.5977 - val_auc: 0.5456 - val_loss: 0.0681 - val_precision: 0.5975 - val_recall: 0.9947 - learning_rate: 1.0000e-04
# Epoch 7/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6009 - auc: 0.5298 - loss: 0.0730 - precision: 0.6042 - recall: 0.9769
# Epoch 7: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6009 - auc: 0.5298 - loss: 0.0730 - precision: 0.6042 - recall: 0.9769 - val_accuracy: 0.5966 - val_auc: 0.5328 - val_loss: 0.0688 - val_precision: 0.5970 - val_recall: 0.9929 - learning_rate: 1.0000e-04
# Epoch 8/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6034 - auc: 0.5186 - loss: 0.0728 - precision: 0.6048 - recall: 0.9843
# Epoch 8: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 271ms/step - accuracy: 0.6033 - auc: 0.5186 - loss: 0.0728 - precision: 0.6048 - recall: 0.9843 - val_accuracy: 0.5987 - val_auc: 0.5337 - val_loss: 0.0691 - val_precision: 0.5981 - val_recall: 0.9947 - learning_rate: 1.0000e-04
# Epoch 9/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6034 - auc: 0.5363 - loss: 0.0712 - precision: 0.6046 - recall: 0.9860
# Epoch 9: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6034 - auc: 0.5362 - loss: 0.0712 - precision: 0.6046 - recall: 0.9860 - val_accuracy: 0.5987 - val_auc: 0.5260 - val_loss: 0.0688 - val_precision: 0.5975 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 10/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6045 - auc: 0.5288 - loss: 0.0715 - precision: 0.6054 - recall: 0.9857
# Epoch 10: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6045 - auc: 0.5289 - loss: 0.0715 - precision: 0.6053 - recall: 0.9857 - val_accuracy: 0.5998 - val_auc: 0.5310 - val_loss: 0.0687 - val_precision: 0.5981 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 11/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6005 - auc: 0.5136 - loss: 0.0721 - precision: 0.6025 - recall: 0.9887
# Epoch 11: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6005 - auc: 0.5137 - loss: 0.0721 - precision: 0.6024 - recall: 0.9887 - val_accuracy: 0.5966 - val_auc: 0.5274 - val_loss: 0.0692 - val_precision: 0.5970 - val_recall: 0.9929 - learning_rate: 1.0000e-04
# Epoch 12/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6068 - auc: 0.5238 - loss: 0.0711 - precision: 0.6056 - recall: 0.9943
# Epoch 12: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6067 - auc: 0.5238 - loss: 0.0711 - precision: 0.6055 - recall: 0.9942 - val_accuracy: 0.6008 - val_auc: 0.5319 - val_loss: 0.0689 - val_precision: 0.5987 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 13/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6056 - auc: 0.5332 - loss: 0.0706 - precision: 0.6050 - recall: 0.9935
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 13: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6055 - auc: 0.5331 - loss: 0.0706 - precision: 0.6049 - recall: 0.9935 - val_accuracy: 0.5998 - val_auc: 0.5173 - val_loss: 0.0691 - val_precision: 0.5989 - val_recall: 0.9929 - learning_rate: 1.0000e-04
# Epoch 14/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6081 - auc: 0.5360 - loss: 0.0702 - precision: 0.6064 - recall: 0.9950
# Epoch 14: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6080 - auc: 0.5360 - loss: 0.0702 - precision: 0.6063 - recall: 0.9950 - val_accuracy: 0.5998 - val_auc: 0.5132 - val_loss: 0.0696 - val_precision: 0.5989 - val_recall: 0.9929 - learning_rate: 5.0000e-05
# Epoch 15/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6027 - auc: 0.5209 - loss: 0.0710 - precision: 0.6030 - recall: 0.9954
# Epoch 15: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6027 - auc: 0.5209 - loss: 0.0710 - precision: 0.6029 - recall: 0.9954 - val_accuracy: 0.5998 - val_auc: 0.5200 - val_loss: 0.0693 - val_precision: 0.5989 - val_recall: 0.9929 - learning_rate: 5.0000e-05
# Epoch 16/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6010 - auc: 0.5273 - loss: 0.0707 - precision: 0.6027 - recall: 0.9898
# Epoch 16: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6010 - auc: 0.5273 - loss: 0.0707 - precision: 0.6026 - recall: 0.9898 - val_accuracy: 0.5987 - val_auc: 0.5272 - val_loss: 0.0692 - val_precision: 0.5983 - val_recall: 0.9929 - learning_rate: 5.0000e-05
# Epoch 17/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6095 - auc: 0.5551 - loss: 0.0691 - precision: 0.6069 - recall: 0.9970
# Epoch 17: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 271ms/step - accuracy: 0.6094 - auc: 0.5550 - loss: 0.0692 - precision: 0.6069 - recall: 0.9970 - val_accuracy: 0.5977 - val_auc: 0.5239 - val_loss: 0.0694 - val_precision: 0.5979 - val_recall: 0.9912 - learning_rate: 5.0000e-05
# Epoch 18/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6037 - auc: 0.4949 - loss: 0.0716 - precision: 0.6037 - recall: 0.9946
# Epoch 18: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 271ms/step - accuracy: 0.6037 - auc: 0.4951 - loss: 0.0716 - precision: 0.6036 - recall: 0.9946 - val_accuracy: 0.5956 - val_auc: 0.5298 - val_loss: 0.0693 - val_precision: 0.5968 - val_recall: 0.9894 - learning_rate: 5.0000e-05
# Epoch 19/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6026 - auc: 0.5295 - loss: 0.0704 - precision: 0.6034 - recall: 0.9915
# Epoch 19: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6025 - auc: 0.5295 - loss: 0.0704 - precision: 0.6033 - recall: 0.9915 - val_accuracy: 0.5998 - val_auc: 0.5224 - val_loss: 0.0692 - val_precision: 0.5983 - val_recall: 0.9982 - learning_rate: 5.0000e-05
# Epoch 20/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6052 - auc: 0.5382 - loss: 0.0696 - precision: 0.6044 - recall: 0.9960
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 20: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6051 - auc: 0.5381 - loss: 0.0696 - precision: 0.6044 - recall: 0.9960 - val_accuracy: 0.5987 - val_auc: 0.5138 - val_loss: 0.0694 - val_precision: 0.5981 - val_recall: 0.9947 - learning_rate: 5.0000e-05
# Epoch 21/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6058 - auc: 0.5529 - loss: 0.0690 - precision: 0.6049 - recall: 0.9954
# Epoch 21: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6057 - auc: 0.5528 - loss: 0.0690 - precision: 0.6048 - recall: 0.9954 - val_accuracy: 0.5987 - val_auc: 0.5044 - val_loss: 0.0696 - val_precision: 0.5983 - val_recall: 0.9929 - learning_rate: 2.5000e-05
# Epoch 22/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6063 - auc: 0.5188 - loss: 0.0703 - precision: 0.6056 - recall: 0.9921
# Epoch 22: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 271ms/step - accuracy: 0.6063 - auc: 0.5190 - loss: 0.0703 - precision: 0.6055 - recall: 0.9921 - val_accuracy: 0.5977 - val_auc: 0.5199 - val_loss: 0.0693 - val_precision: 0.5981 - val_recall: 0.9894 - learning_rate: 2.5000e-05
# Epoch 23/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6058 - auc: 0.5223 - loss: 0.0702 - precision: 0.6047 - recall: 0.9969
# Epoch 23: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6058 - auc: 0.5223 - loss: 0.0702 - precision: 0.6047 - recall: 0.9969 - val_accuracy: 0.5977 - val_auc: 0.5276 - val_loss: 0.0693 - val_precision: 0.5981 - val_recall: 0.9894 - learning_rate: 2.5000e-05
# Epoch 24/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6084 - auc: 0.5414 - loss: 0.0692 - precision: 0.6065 - recall: 0.9949
# Epoch 24: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 271ms/step - accuracy: 0.6083 - auc: 0.5413 - loss: 0.0692 - precision: 0.6065 - recall: 0.9949 - val_accuracy: 0.5977 - val_auc: 0.5283 - val_loss: 0.0693 - val_precision: 0.5981 - val_recall: 0.9894 - learning_rate: 2.5000e-05
# Epoch 25/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6040 - auc: 0.5228 - loss: 0.0703 - precision: 0.6038 - recall: 0.9950
# Epoch 25: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6040 - auc: 0.5228 - loss: 0.0703 - precision: 0.6038 - recall: 0.9950 - val_accuracy: 0.5977 - val_auc: 0.5294 - val_loss: 0.0692 - val_precision: 0.5981 - val_recall: 0.9894 - learning_rate: 2.5000e-05
# Epoch 26/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6037 - auc: 0.5171 - loss: 0.0708 - precision: 0.6037 - recall: 0.9945
# Epoch 26: val_auc did not improve from 0.54562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 32s 272ms/step - accuracy: 0.6037 - auc: 0.5172 - loss: 0.0708 - precision: 0.6037 - recall: 0.9946 - val_accuracy: 0.5977 - val_auc: 0.5307 - val_loss: 0.0692 - val_precision: 0.5981 - val_recall: 0.9894 - learning_rate: 2.5000e-05
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === Classification Report ===
#               precision    recall  f1-score   support
#
#           FP     0.5938    0.0494    0.0911       385
#           CP     0.6022    0.9771    0.7451       567
#
#     accuracy                         0.6019       952
#    macro avg     0.5980    0.5132    0.4181       952
# weighted avg     0.5988    0.6019    0.4806       952
#
#
# ✅ Modèle et seuil sauvegardés dans /kaggle/working/
#
# [VISUALISATION] Génération des graphiques...
# ✔ Graphiques sauvegardés dans /kaggle/working/lstm_results.png
